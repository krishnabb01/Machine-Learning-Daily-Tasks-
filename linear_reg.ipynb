# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnabb01/Machine-Learning-Daily-Tasks-/blob/main/linear_reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
df=pd.read_csv(r"/content/data.csv")

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.160661  0.005679  0.922717
# Pulse    -0.160661  1.000000  0.784631  0.025121
# Maxpulse  0.005679  0.784631  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
x = df.Duration
y = df.Calories

# %%
m,c,rvalue,pvalue,stderr = stats.linregress(x,y)

# %%
def predictiveline(x):
  return m * x + c

# %%
predy = list(map(predictiveline,x))

# %%
plt.scatter(x,y)
plt.plot(x,predy)
plt.show()

# %%
print(rvalue)
# Out:
# 0.9227166783472455
