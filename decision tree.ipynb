# %% [markdown]
# 1. Load and Explore the Dataset: Load the dataset into a Pandas DataFrame and explore the data to understand its structure and contents.

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\\Users\\Krishna Baraskar\\Downloads\\medical_dataset - medical_dataset.csv")
df.head()
# Out:
#    Age  Blood_Pressure  Cholesterol  Heart_Rate  Smoking_Status  Diabetes  \
# 0   58              86          271          90               0         0
# 1   71             136          200          80               0         0
# 2   48             115          296          76               1         0
# 3   34             124          170          82               0         0
# 4   62              99          154          96               0         0
#
#    Family_History Exercise_Level  Disease
# 0               0            Low        0
# 1               0           High        0
# 2               0            Low        0
# 3               0            Low        0
# 4               0           High        0

# %%
df.tail()
# Out:
#      Age  Blood_Pressure  Cholesterol  Heart_Rate  Smoking_Status  Diabetes  \
# 495   69             106          161          88               1         0
# 496   44             172          211          69               0         0
# 497   43             111          229          71               0         0
# 498   32             129          232          89               1         0
# 499   79             140          157          60               1         1
#
#      Family_History Exercise_Level  Disease
# 495               1            Low        0
# 496               0         Medium        0
# 497               1            Low        0
# 498               0         Medium        0
# 499               0         Medium        1

# %% [markdown]
# 2. Preprocess the Data: Handle any missing values, encode categorical variables (such as `Exercise_Level`), and scale numerical features if necessary.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             500 non-null    int64
#  1   Blood_Pressure  500 non-null    int64
#  2   Cholesterol     500 non-null    int64
#  3   Heart_Rate      500 non-null    int64
#  4   Smoking_Status  500 non-null    int64
#  5   Diabetes        500 non-null    int64
#  6   Family_History  500 non-null    int64
#  7   Exercise_Level  500 non-null    object
#  8   Disease         500 non-null    int64
# dtypes: int64(8), object(1)
# memory usage: 35.3+ KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Blood_Pressure    0
# Cholesterol       0
# Heart_Rate        0
# Smoking_Status    0
# Diabetes          0
# Family_History    0
# Exercise_Level    0
# Disease           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Exercise_Level"].unique()
# Out:
# array(['Low', 'High', 'Medium'], dtype=object)

# %%
df.replace(to_replace=["Low"],value=1,inplace=True)
df.replace(to_replace=["High"],value=5,inplace=True)
df.replace(to_replace=["Medium"],value=10,inplace=True)
# Out:
# C:\Users\Krishna Baraskar\AppData\Local\Temp\ipykernel_25760\4078898380.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(to_replace=["Medium"],value=10,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             500 non-null    int64
#  1   Blood_Pressure  500 non-null    int64
#  2   Cholesterol     500 non-null    int64
#  3   Heart_Rate      500 non-null    int64
#  4   Smoking_Status  500 non-null    int64
#  5   Diabetes        500 non-null    int64
#  6   Family_History  500 non-null    int64
#  7   Exercise_Level  500 non-null    int64
#  8   Disease         500 non-null    int64
# dtypes: int64(9)
# memory usage: 35.3 KB

# %%
df.describe()
# Out:
#               Age  Blood_Pressure  Cholesterol  Heart_Rate  Smoking_Status  \
# count  500.000000      500.000000   500.000000  500.000000      500.000000
# mean    50.396000      129.566000   222.146000   79.874000        0.268000
# std     17.335982       29.433694    43.371822   11.354293        0.443361
# min     20.000000       80.000000   150.000000   60.000000        0.000000
# 25%     36.750000      103.000000   185.000000   70.750000        0.000000
# 50%     51.000000      131.000000   219.000000   79.500000        0.000000
# 75%     65.000000      154.000000   260.000000   90.000000        1.000000
# max     79.000000      179.000000   299.000000   99.000000        1.000000
#
#          Diabetes  Family_History  Exercise_Level     Disease
# count  500.000000      500.000000      500.000000  500.000000
# mean     0.138000        0.426000        5.164000    0.322000
# std      0.345245        0.494989        3.682965    0.467711
# ...

# %%
sb.stripplot(y= "Age",data = df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             500 non-null    int64
#  1   Blood_Pressure  500 non-null    int64
#  2   Cholesterol     500 non-null    int64
#  3   Heart_Rate      500 non-null    int64
#  4   Smoking_Status  500 non-null    int64
#  5   Diabetes        500 non-null    int64
#  6   Family_History  500 non-null    int64
#  7   Exercise_Level  500 non-null    int64
#  8   Disease         500 non-null    int64
# dtypes: int64(9)
# memory usage: 35.3 KB

# %%
df.corr()
# Out:
#                      Age  Blood_Pressure  Cholesterol  Heart_Rate  \
# Age             1.000000        0.022645    -0.080076   -0.001192
# Blood_Pressure  0.022645        1.000000    -0.058746   -0.024060
# Cholesterol    -0.080076       -0.058746     1.000000    0.043421
# Heart_Rate     -0.001192       -0.024060     0.043421    1.000000
# Smoking_Status -0.039648        0.042101    -0.062276    0.015081
# Diabetes        0.027682       -0.024662     0.053256   -0.002201
# Family_History  0.000386       -0.007367    -0.040055    0.076961
# Exercise_Level  0.047286        0.013672     0.058338   -0.025623
# Disease         0.447415        0.418646     0.144184   -0.044799
#
#                 Smoking_Status  Diabetes  Family_History  Exercise_Level  \
# Age                  -0.039648  0.027682        0.000386        0.047286
# Blood_Pressure        0.042101 -0.024662       -0.007367        0.013672
# Cholesterol          -0.062276  0.053256       -0.040055        0.058338
# ...

# %%
df["Disease"].tail()
# Out:
# 495    0
# 496    0
# 497    0
# 498    0
# 499    1
# Name: Disease, dtype: int64

# %% [markdown]
# 3. Split the Data: Split the dataset into training and testing sets using an 80-20 split.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.drop(["Disease"],axis="columns"),df["Disease"],test_size = 0.2)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 400
# 100
# 400
# 100

# %% [markdown]
# 4. Train a Decision Tree Model: Train a Decision Tree classifier on the training data to predict whether a patient has heart disease.

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# 5. Evaluate the Model: Evaluate the performance of the model using appropriate metrics such as accuracy, precision, recall, and the confusion matrix.

# %%
model.score(x_test,y_test)*100
# Out:
# 100.0

# %%
y_predi = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
accuracy = accuracy_score(y_test, y_predi)
print(f"Accuracy: {accuracy:.2f}")
precision = precision_score(y_test, y_predi)
print(f"Precision: {precision:.2f}")
recall = recall_score(y_test, y_predi)
print(f"Recall: {recall:.2f}")
cm = confusion_matrix(y_test, y_predi)
print("Confusion Matrix:")
print(cm)
# Out:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Confusion Matrix:
# [[74  0]
#  [ 0 26]]

# %%
plt.figure(figsize=(8,5))
sb.heatmap(cm, annot=True, fmt=".0f", cbar_kws={'format': '%.0f'})
plt.xlabel("Predicted")
plt.ylabel("Truth")
plt.show()

# %% [markdown]
# 6. Visualize the Decision Tree: Visualize the trained Decision Tree to understand the decision-making process of the model.

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20, 10))
plot_tree(model, filled=True, feature_names=x_test.columns, class_names=True)
plt.show()

# %% [markdown]
# 7. Interpret the Results: Provide an interpretation of the results. Discuss the most important features contributing to the prediction of heart disease and any potential overfitting or underfitting issues with the model.

# %%
feature_importance = model.feature_importances_

# %%
features = x_test.columns
importance_df = pd.DataFrame({'Feature': features, 'Importance': feature_importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# %%
print(importance_df)
# Out:
#           Feature  Importance
# 1  Blood_Pressure    0.317307
# 0             Age    0.286047
# 2     Cholesterol    0.151334
# 4  Smoking_Status    0.115695
# 5        Diabetes    0.084357
# 6  Family_History    0.045261
# 3      Heart_Rate    0.000000
# 7  Exercise_Level    0.000000

# %%
# the most important features contributing to the prediction of heart disease
importance_df.head(1)
# Out:
#           Feature  Importance
# 1  Blood_Pressure    0.317307

# %%
train_accuracy = model.score(x_train, y_train)
print(f"Training Accuracy: {train_accuracy}")

test_accuracy = model.score(x_test, y_test)
print(f"Test Accuracy: {test_accuracy}")

# If Training Accuracy >> Test Accuracy: The model is likely overfitting.
# If Training Accuracy ≈ Test Accuracy but both are low: The model might be underfitting.
# Out:
# Training Accuracy: 1.0
# Test Accuracy: 1.0
